# %% [markdown]
# # Tests

# %%
import pytest

# %% [markdown]
# ## Test_perception

# %%
pytest.main(["Tests/test_perception.py", "-v"])
# Out:
# ============================= test session starts =============================
# platform win32 -- Python 3.10.11, pytest-9.1.1, pluggy-1.6.0 -- c:\Users\3058388\AppData\Local\Programs\Python\Python310\python.exe
# cachedir: .pytest_cache
# rootdir: c:\Sandeep Gupta\01. Workspaces\wsAgentADO
# plugins: anyio-4.13.0, typeguard-4.5.2
# collecting ... collected 4 items
#
# Tests/test_perception.py::test_update_navs_rejects_spoofed_feed PASSED   [ 25%]
# Tests/test_perception.py::test_update_navs_accepts_plausible_move PASSED [ 50%]
# Tests/test_perception.py::test_add_fund_rejects_non_positive_values PASSED [ 75%]
# Tests/test_perception.py::test_add_fund_rejects_duplicate PASSED         [100%]
#
# ============================== warnings summary ===============================
# ..\..\..\Users\3058388\AppData\Local\Programs\Python\Python310\lib\site-packages\matplotlib\_fontconfig_pattern.py:88
# ..\..\..\Users\3058388\AppData\Local\Programs\Python\Python310\lib\site-packages\matplotlib\_fontconfig_pattern.py:88
# ..\..\..\Users\3058388\AppData\Local\Programs\Python\Python310\lib\site-packages\matplotlib\_fontconfig_pattern.py:88
# ..\..\..\Users\3058388\AppData\Local\Programs\Python\Python310\lib\site-packages\matplotlib\_fontconfig_pattern.py:88
# ..\..\..\Users\3058388\AppData\Local\Programs\Python\Python310\lib\site-packages\matplotlib\_fontconfig_pattern.py:88
# ..\..\..\Users\3058388\AppData\Local\Programs\Python\Python310\lib\site-packages\matplotlib\_fontconfig_pattern.py:88
#   c:\Users\3058388\AppData\Local\Programs\Python\Python310\lib\site-packages\matplotlib\_fontconfig_pattern.py:88: PyparsingDeprecationWarning: 'parseString' deprecated - use 'parse_string'
#     parse = parser.parseString(pattern)
#
# ..\..\..\Users\3058388\AppData\Local\Programs\Python\Python310\lib\site-packages\matplotlib\_fontconfig_pattern.py:92
# ..\..\..\Users\3058388\AppData\Local\Programs\Python\Python310\lib\site-packages\matplotlib\_fontconfig_pattern.py:92
# ..\..\..\Users\3058388\AppData\Local\Programs\Python\Python310\lib\site-packages\matplotlib\_fontconfig_pattern.py:92
# ..\..\..\Users\3058388\AppData\Local\Programs\Python\Python310\lib\site-packages\matplotlib\_fontconfig_pattern.py:92
# ..\..\..\Users\3058388\AppData\Local\Programs\Python\Python310\lib\site-packages\matplotlib\_fontconfig_pattern.py:92
# ..\..\..\Users\3058388\AppData\Local\Programs\Python\Python310\lib\site-packages\matplotlib\_fontconfig_pattern.py:92
#   c:\Users\3058388\AppData\Local\Programs\Python\Python310\lib\site-packages\matplotlib\_fontconfig_pattern.py:92: PyparsingDeprecationWarning: 'resetCache' deprecated - use 'reset_cache'
#     parser.resetCache()
#
# ..\..\..\Users\3058388\AppData\Local\Programs\Python\Python310\lib\site-packages\matplotlib\_mathtext.py:45
#   c:\Users\3058388\AppData\Local\Programs\Python\Python310\lib\site-packages\matplotlib\_mathtext.py:45: PyparsingDeprecationWarning: 'enablePackrat' deprecated - use 'enable_packrat'
#     ParserElement.enablePackrat()
#
# -- Docs: https://docs.pytest.org/en/stable/how-to/capture-warnings.html
# ======================= 4 passed, 13 warnings in 0.15s ========================
# <ExitCode.OK: 0>

# %% [markdown]
# ## Test_reasoning

# %%
pytest.main(["Tests/test_reasoning.py", "-v"])
# Out:
# ============================= test session starts =============================
# platform win32 -- Python 3.10.11, pytest-9.1.1, pluggy-1.6.0 -- c:\Users\3058388\AppData\Local\Programs\Python\Python310\python.exe
# cachedir: .pytest_cache
# rootdir: c:\Sandeep Gupta\01. Workspaces\wsAgentADO
# plugins: anyio-4.13.0, typeguard-4.5.2
# collecting ... collected 1 item
#
# Tests/test_reasoning.py::test_plan_rejects_out_of_catalog_subgoals PASSED [100%]
#
# ============================== 1 passed in 0.06s ==============================
# <ExitCode.OK: 0>

# %% [markdown]
# ## Test_controlled_framework

# %%
pytest.main(["Tests/test_controlled_framework.py", "-v"])
# Out:
# ============================= test session starts =============================
# platform win32 -- Python 3.10.11, pytest-9.1.1, pluggy-1.6.0 -- c:\Users\3058388\AppData\Local\Programs\Python\Python310\python.exe
# cachedir: .pytest_cache
# rootdir: c:\Sandeep Gupta\01. Workspaces\wsAgentADO
# plugins: anyio-4.13.0, typeguard-4.5.2
# collecting ... collected 25 items
#
# Tests/test_controlled_framework.py::test_acp1_adapter_publishes_rejections PASSED [  4%]
# Tests/test_controlled_framework.py::test_acp1_adapter_silent_when_nothing_rejected PASSED [  8%]
# Tests/test_controlled_framework.py::test_acp2_adapter_detects_full_catalog_echo PASSED [ 12%]
# Tests/test_controlled_framework.py::test_acp2_adapter_no_false_positive_on_normal_plan PASSED [ 16%]
# Tests/test_controlled_framework.py::test_acp2_marker_string_matches_source PASSED [ 20%]
# Tests/test_controlled_framework.py::test_acp3_adapter_flags_grounded_fallback PASSED [ 24%]
# Tests/test_controlled_framework.py::test_acp3_adapter_flags_ungrounded_currency_if_it_ever_slips_through PASSED [ 28%]
# Tests/test_controlled_framework.py::test_acp6_adapter_publishes_bias_signal PASSED [ 32%]
# Tests/test_controlled_framework.py::test_acp6_adapter_silent_when_no_bias PASSED [ 36%]
# Tests/test_controlled_framework.py::test_autonomy_boundary_escalates_irreversible_tool PASSED [ 40%]
# Tests/test_controlled_framework.py::test_autonomy_boundary_persistence_limit_forces_escalation PASSED [ 44%]
# Tests/test_controlled_framework.py::test_autonomy_boundary_rejects_unmapped_subgoal PASSED [ 48%]
# Tests/test_controlled_framework.py::test_delegation_expires_by_ttl PASSED [ 52%]
# Tests/test_controlled_framework.py::test_delegation_expires_by_invocation_count PASSED [ 56%]
# Tests/test_controlled_framework.py::test_delegation_cascade_revoke PASSED [ 60%]
# Tests/test_controlled_framework.py::test_delegation_revoke_does_not_affect_siblings PASSED [ 64%]
# Tests/test_controlled_framework.py::test_gate_denies_on_missing_permission PASSED [ 68%]
# Tests/test_controlled_framework.py::test_gate_denies_on_expired_grant PASSED [ 72%]
# Tests/test_controlled_framework.py::test_gate_denies_over_tier PASSED    [ 76%]
# Tests/test_controlled_framework.py::test_gate_denies_over_impact_budget PASSED [ 80%]
# Tests/test_controlled_framework.py::test_gate_denies_when_circuit_breaker_tripped PASSED [ 84%]
# Tests/test_controlled_framework.py::test_run_id_propagates_to_acp5_authorize_events PASSED [ 88%]
# Tests/test_controlled_framework.py::test_closed_loop_trips_tool_breaker_after_repeated_acp1_rejects PASSED [ 92%]
# Tests/test_controlled_framework.py::test_closed_loop_trips_run_breaker_on_acp6_bias PASSED [ 96%]
# Tests/test_controlled_framework.py::test_render_readout_delegation_is_session_scoped_not_run_scoped PASSED [100%]
#
# ============================= 25 passed in 0.31s ==============================
# <ExitCode.OK: 0>
