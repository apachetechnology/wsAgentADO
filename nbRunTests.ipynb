# %% [markdown]
# # Tests

# %%
import pytest

# %%
pytest.main(["Tests/conftest.py", "-v"])
# Out:
# ============================= test session starts =============================
# platform win32 -- Python 3.10.11, pytest-9.1.1, pluggy-1.6.0 -- c:\Users\3058388\AppData\Local\Programs\Python\Python310\python.exe
# cachedir: .pytest_cache
# rootdir: c:\Sandeep Gupta\01. Workspaces\wsAgentADO
# plugins: anyio-4.13.0, typeguard-4.5.2
# collecting ... collected 0 items
#
# ============================ no tests ran in 0.06s ============================
# <ExitCode.NO_TESTS_COLLECTED: 5>

# %% [markdown]
# ## Test_perception_redteam

# %%
pytest.main(["Tests/test_perception_redteam.py", "-v"])

# %% [markdown]
# ## Test_reasoning_redteam

# %%
pytest.main(["Tests/test_reasoning_redteam.py", "-v"])
# Out:
# ============================= test session starts =============================
# platform win32 -- Python 3.10.11, pytest-9.1.1, pluggy-1.6.0 -- c:\Users\3058388\AppData\Local\Programs\Python\Python310\python.exe
# cachedir: .pytest_cache
# rootdir: c:\Sandeep Gupta\01. Workspaces\wsAgentADO
# plugins: anyio-4.13.0, typeguard-4.5.2
# collecting ... collected 1 item
#
# Tests/test_reasoning_redteam.py::test_plan_rejects_out_of_catalog_subgoals PASSED [100%]
#
# ======================== 1 passed in 92.03s (0:01:32) =========================
# <ExitCode.OK: 0>
